# %%
import sys
import gymnasium
import os
import pandas as pd
from matplotlib import pyplot as plt
# this is required as stated in https://github.com/DLR-RM/stable-baselines3/pull/780
sys.modules["gym"] = gymnasium

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.monitor import Monitor

from building_energy_storage_simulation import Simulation, Environment

# %% [markdown]
# # Applying Reiforcement Learning Using Stable Baselines 3
#
# Note: The stable release of [https://github.com/DLR-RM/stable-baselines3](https://github.com/DLR-RM/stable-baselines3) does not support `gymnasium` yet. Therefore make sure to install sb3 by: `pip install git+https://github.com/carlosluis/stable-baselines3@fix_tests`.
#
# Check [here](https://github.com/DLR-RM/stable-baselines3/pull/780) for more info

# %%
RL_PATH = 'rl_example/'
os.makedirs(RL_PATH, exist_ok=True)

# Create Environment
env = Environment(solar_power_installed=300)
# Wrap with Monitor() so a log of the training is saved 
env = Monitor(env, filename=RL_PATH)
# Warp with DummyVecEnc() so the observations and reward can be normalized using VecNormalize()
env = DummyVecEnv([lambda: env])
env = VecNormalize(env, norm_obs=True, norm_reward=True)

# %%
# Train with PPO :-)
model = PPO("MlpPolicy", env, verbose=1, gamma=0.95)
model.learn(total_timesteps=100000)
# Store the trained Model and environment stats (which are needed as we are standadizing the observations and reward using VecNormalize())
model.save(RL_PATH + 'model')
env.save(RL_PATH + 'env.pkl')
# Out:
# Using cpu device
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2e+03     |
# |    ep_rew_mean     | -2.04e+06 |
# | time/              |           |
# |    fps             | 863       |
# |    iterations      | 1         |
# |    time_elapsed    | 2         |
# |    total_timesteps | 2048      |
# ----------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -2.05e+06    |
# | time/                   |              |
# |    fps                  | 693          |
# |    iterations           | 2            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0052354354 |
# |    clip_fraction        | 0.0328       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.0244      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00132     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00478     |
# |    std                  | 0.988        |
# |    value_loss           | 0.262        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -2.05e+06    |
# | time/                   |              |
# |    fps                  | 692          |
# |    iterations           | 3            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0049185525 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.533        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000228     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00291     |
# |    std                  | 0.983        |
# |    value_loss           | 0.0242       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -2.04e+06    |
# | time/                   |              |
# |    fps                  | 706          |
# |    iterations           | 4            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0056182686 |
# |    clip_fraction        | 0.0655       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.682        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0121       |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00529     |
# |    std                  | 0.979        |
# |    value_loss           | 0.0254       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | -2.04e+06   |
# | time/                   |             |
# |    fps                  | 710         |
# |    iterations           | 5           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.004336077 |
# |    clip_fraction        | 0.0192      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.702       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0172      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00164    |
# |    std                  | 0.999       |
# |    value_loss           | 0.0252      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | -2.04e+06   |
# | time/                   |             |
# |    fps                  | 726         |
# |    iterations           | 6           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.003718331 |
# |    clip_fraction        | 0.0237      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.699       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000695   |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00364    |
# |    std                  | 0.998       |
# |    value_loss           | 0.025       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | -2.03e+06   |
# | time/                   |             |
# |    fps                  | 719         |
# |    iterations           | 7           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.005202961 |
# |    clip_fraction        | 0.0449      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.694       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00125    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00558    |
# |    std                  | 1           |
# |    value_loss           | 0.0237      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -2.03e+06    |
# | time/                   |              |
# |    fps                  | 724          |
# |    iterations           | 8            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0047069453 |
# |    clip_fraction        | 0.0424       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.71         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0032      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00326     |
# |    std                  | 1            |
# |    value_loss           | 0.0244       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -2.02e+06    |
# | time/                   |              |
# |    fps                  | 729          |
# |    iterations           | 9            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0043668267 |
# |    clip_fraction        | 0.039        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.728        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00898      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00289     |
# |    std                  | 1.02         |
# |    value_loss           | 0.0236       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -2.02e+06    |
# | time/                   |              |
# |    fps                  | 728          |
# |    iterations           | 10           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0030843914 |
# |    clip_fraction        | 0.0256       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.711        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00343      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00274     |
# |    std                  | 1.02         |
# |    value_loss           | 0.0233       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -2.01e+06    |
# | time/                   |              |
# |    fps                  | 727          |
# |    iterations           | 11           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0056389477 |
# |    clip_fraction        | 0.0397       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.72         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0016       |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00324     |
# |    std                  | 1.02         |
# |    value_loss           | 0.0253       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | -2.01e+06   |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 12          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.003090657 |
# |    clip_fraction        | 0.0301      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.72        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0145      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00202    |
# |    std                  | 1.02        |
# |    value_loss           | 0.0243      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -2e+06       |
# | time/                   |              |
# |    fps                  | 735          |
# |    iterations           | 13           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0029549445 |
# |    clip_fraction        | 0.0321       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.731        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00142     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00253     |
# |    std                  | 1.01         |
# |    value_loss           | 0.024        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -2e+06       |
# | time/                   |              |
# |    fps                  | 734          |
# |    iterations           | 14           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0045801033 |
# |    clip_fraction        | 0.0382       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.726        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000767     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0036      |
# |    std                  | 0.988        |
# |    value_loss           | 0.0239       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -2e+06       |
# | time/                   |              |
# |    fps                  | 733          |
# |    iterations           | 15           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0041521564 |
# |    clip_fraction        | 0.0441       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.734        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00446     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00454     |
# |    std                  | 0.984        |
# |    value_loss           | 0.0249       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -1.99e+06    |
# | time/                   |              |
# |    fps                  | 733          |
# |    iterations           | 16           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0036362482 |
# |    clip_fraction        | 0.0433       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.723        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0138      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00382     |
# |    std                  | 0.974        |
# |    value_loss           | 0.0249       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | -1.99e+06   |
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 17          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.004928954 |
# |    clip_fraction        | 0.0386      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.744       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00397     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0044     |
# |    std                  | 0.985       |
# |    value_loss           | 0.0257      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -1.99e+06    |
# | time/                   |              |
# |    fps                  | 733          |
# |    iterations           | 18           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0029364366 |
# |    clip_fraction        | 0.0379       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.738        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000964     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00342     |
# |    std                  | 0.977        |
# |    value_loss           | 0.0246       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -1.99e+06    |
# | time/                   |              |
# |    fps                  | 733          |
# |    iterations           | 19           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0034179988 |
# |    clip_fraction        | 0.0332       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.743        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000188     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00256     |
# |    std                  | 0.978        |
# |    value_loss           | 0.0236       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | -1.99e+06   |
# | time/                   |             |
# |    fps                  | 729         |
# |    iterations           | 20          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.003083027 |
# |    clip_fraction        | 0.0306      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.733       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00725     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00287    |
# |    std                  | 0.972       |
# |    value_loss           | 0.0248      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -1.99e+06    |
# | time/                   |              |
# |    fps                  | 732          |
# |    iterations           | 21           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0048447037 |
# |    clip_fraction        | 0.039        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.738        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000193    |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00467     |
# |    std                  | 0.966        |
# |    value_loss           | 0.0249       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | -1.98e+06   |
# | time/                   |             |
# |    fps                  | 736         |
# |    iterations           | 22          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.004050977 |
# |    clip_fraction        | 0.0499      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.729       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00914    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00386    |
# |    std                  | 0.951       |
# |    value_loss           | 0.0242      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -1.98e+06    |
# | time/                   |              |
# |    fps                  | 734          |
# |    iterations           | 23           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0030270035 |
# |    clip_fraction        | 0.0207       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.741        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0117      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00204     |
# |    std                  | 0.953        |
# |    value_loss           | 0.0251       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | -1.98e+06   |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 24          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.005449087 |
# |    clip_fraction        | 0.0405      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.743       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00251     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0026     |
# |    std                  | 0.937       |
# |    value_loss           | 0.0236      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -1.98e+06    |
# | time/                   |              |
# |    fps                  | 730          |
# |    iterations           | 25           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0055820197 |
# |    clip_fraction        | 0.0351       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.741        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00116      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00449     |
# |    std                  | 0.912        |
# |    value_loss           | 0.0238       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | -1.98e+06   |
# | time/                   |             |
# |    fps                  | 728         |
# |    iterations           | 26          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.004464591 |
# |    clip_fraction        | 0.0373      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.734       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0278      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00217    |
# |    std                  | 0.917       |
# |    value_loss           | 0.0247      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -1.98e+06    |
# | time/                   |              |
# |    fps                  | 730          |
# |    iterations           | 27           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0050921906 |
# |    clip_fraction        | 0.0511       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.749        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000272     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00356     |
# |    std                  | 0.913        |
# |    value_loss           | 0.024        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | -1.97e+06   |
# | time/                   |             |
# |    fps                  | 729         |
# |    iterations           | 28          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.004295043 |
# |    clip_fraction        | 0.0387      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.75        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00175    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00298    |
# |    std                  | 0.899       |
# |    value_loss           | 0.0291      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -1.97e+06    |
# | time/                   |              |
# |    fps                  | 730          |
# |    iterations           | 29           |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0056470577 |
# |    clip_fraction        | 0.0579       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.734        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00121      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00481     |
# |    std                  | 0.89         |
# |    value_loss           | 0.0251       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -1.97e+06    |
# | time/                   |              |
# |    fps                  | 725          |
# |    iterations           | 30           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0029341802 |
# |    clip_fraction        | 0.0259       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.74         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00205     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00196     |
# |    std                  | 0.881        |
# |    value_loss           | 0.024        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -1.97e+06    |
# | time/                   |              |
# |    fps                  | 727          |
# |    iterations           | 31           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0039482815 |
# |    clip_fraction        | 0.0421       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.749        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0101       |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00311     |
# |    std                  | 0.891        |
# |    value_loss           | 0.0237       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2e+03      |
# |    ep_rew_mean          | -1.96e+06  |
# | time/                   |            |
# |    fps                  | 725        |
# |    iterations           | 32         |
# |    time_elapsed         | 90         |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.00582534 |
# |    clip_fraction        | 0.0644     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.3       |
# |    explained_variance   | 0.74       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0037     |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.00747   |
# |    std                  | 0.884      |
# |    value_loss           | 0.0237     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | -1.96e+06   |
# | time/                   |             |
# |    fps                  | 718         |
# |    iterations           | 33          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.003915788 |
# |    clip_fraction        | 0.0262      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.749       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00277    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.002      |
# |    std                  | 0.884       |
# |    value_loss           | 0.0225      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -1.96e+06    |
# | time/                   |              |
# |    fps                  | 718          |
# |    iterations           | 34           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0064828694 |
# |    clip_fraction        | 0.0514       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.744        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00622      |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00304     |
# |    std                  | 0.881        |
# |    value_loss           | 0.0237       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -1.96e+06    |
# | time/                   |              |
# |    fps                  | 715          |
# |    iterations           | 35           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0027093634 |
# |    clip_fraction        | 0.0273       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.748        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0104       |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00221     |
# |    std                  | 0.869        |
# |    value_loss           | 0.0234       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2e+03      |
# |    ep_rew_mean          | -1.96e+06  |
# | time/                   |            |
# |    fps                  | 716        |
# |    iterations           | 36         |
# |    time_elapsed         | 102        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.00542219 |
# |    clip_fraction        | 0.0508     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.27      |
# |    explained_variance   | 0.745      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0123     |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.00386   |
# |    std                  | 0.862      |
# |    value_loss           | 0.0239     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | -1.96e+06   |
# | time/                   |             |
# |    fps                  | 716         |
# |    iterations           | 37          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.005858126 |
# |    clip_fraction        | 0.046       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.746       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00628    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00354    |
# |    std                  | 0.85        |
# |    value_loss           | 0.0234      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -1.95e+06    |
# | time/                   |              |
# |    fps                  | 717          |
# |    iterations           | 38           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0025024735 |
# |    clip_fraction        | 0.0332       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.745        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0188       |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00214     |
# |    std                  | 0.862        |
# |    value_loss           | 0.0234       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -1.95e+06    |
# | time/                   |              |
# |    fps                  | 716          |
# |    iterations           | 39           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0039364737 |
# |    clip_fraction        | 0.0314       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.746        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00605      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00127     |
# |    std                  | 0.861        |
# |    value_loss           | 0.023        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | -1.95e+06   |
# | time/                   |             |
# |    fps                  | 716         |
# |    iterations           | 40          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.001943931 |
# |    clip_fraction        | 0.0157      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.742       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0172      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.000933   |
# |    std                  | 0.859       |
# |    value_loss           | 0.0247      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -1.95e+06    |
# | time/                   |              |
# |    fps                  | 717          |
# |    iterations           | 41           |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0046313005 |
# |    clip_fraction        | 0.0623       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.748        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000184     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.0044      |
# |    std                  | 0.856        |
# |    value_loss           | 0.0236       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -1.95e+06    |
# | time/                   |              |
# |    fps                  | 718          |
# |    iterations           | 42           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0028899922 |
# |    clip_fraction        | 0.0376       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.746        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.008       |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00142     |
# |    std                  | 0.85         |
# |    value_loss           | 0.0246       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | -1.94e+06   |
# | time/                   |             |
# |    fps                  | 721         |
# |    iterations           | 43          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.003872303 |
# |    clip_fraction        | 0.0287      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.751       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0122      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00304    |
# |    std                  | 0.838       |
# |    value_loss           | 0.0238      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -1.94e+06    |
# | time/                   |              |
# |    fps                  | 722          |
# |    iterations           | 44           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0043890937 |
# |    clip_fraction        | 0.0241       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.748        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0264       |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00114     |
# |    std                  | 0.837        |
# |    value_loss           | 0.0243       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -1.94e+06    |
# | time/                   |              |
# |    fps                  | 724          |
# |    iterations           | 45           |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0028619762 |
# |    clip_fraction        | 0.0247       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.75         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00178      |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.000973    |
# |    std                  | 0.833        |
# |    value_loss           | 0.0236       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -1.94e+06    |
# | time/                   |              |
# |    fps                  | 725          |
# |    iterations           | 46           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0053132703 |
# |    clip_fraction        | 0.0421       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.749        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00278      |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00227     |
# |    std                  | 0.83         |
# |    value_loss           | 0.0243       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -1.94e+06    |
# | time/                   |              |
# |    fps                  | 721          |
# |    iterations           | 47           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0037030238 |
# |    clip_fraction        | 0.0212       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.751        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000576     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00257     |
# |    std                  | 0.81         |
# |    value_loss           | 0.0243       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -1.93e+06    |
# | time/                   |              |
# |    fps                  | 722          |
# |    iterations           | 48           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0066363635 |
# |    clip_fraction        | 0.0716       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.754        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00924     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00421     |
# |    std                  | 0.816        |
# |    value_loss           | 0.0232       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -1.93e+06    |
# | time/                   |              |
# |    fps                  | 721          |
# |    iterations           | 49           |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0037732199 |
# |    clip_fraction        | 0.0597       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.75         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0247       |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00426     |
# |    std                  | 0.814        |
# |    value_loss           | 0.023        |
# ------------------------------------------

# %% [markdown]
# # Evaluation

# %%
# Plot the training process
training_log = pd.read_csv(RL_PATH + 'monitor.csv', skiprows=1)
training_log['r'].plot()
# Out:
# <Axes: >

# %%
env.training = False

actions, observations, electricity_consumption, excess_energy, rewards = ([], [], [], [], [])
done = False
obs = env.reset()
while not done:
        action = model.predict(obs, deterministic=True)
        obs, r, done, info = env.step([action[0][0]])

        actions.append(action[0][0][0])
        original_reward = env.get_original_reward()[0]
        original_obs = env.get_original_obs()[0]
        observations.append(original_obs)
        electricity_consumption.append(info[0]['electricity_consumption'])
        excess_energy.append(info[0]['excess_energy'])
        rewards.append(r)
        
trajectory = pd.DataFrame({
        'action': actions,
        'observations': observations,
        'electricity_consumption': electricity_consumption,
        'excess_energy': excess_energy,
        'reward': rewards
    })

# %%
plot_data = trajectory[0:200]
observation_df = plot_data['observations'].apply(pd.Series)

plt.rcParams["figure.figsize"] = (16,10)

fig, ax = plt.subplots()
#ax.plot(observation_df[0], label = 'state of charge')
ax.plot(observation_df[1], label = 'electric load')
ax.plot(observation_df[5], label = 'solar generation')
#ax.plot(plot_data['excess_energy'], label = 'excess energy')
#ax.plot(plot_data['electricity_consumption'], label = 'electricity consumption')

ax1 = ax.twinx()
ax1.plot(plot_data['action'], label = 'action', color = 'black')
fig.legend(bbox_to_anchor=[0.5, 0.95], loc = 'center', ncol=5, prop={'size': 16})

# %% [markdown]
# # Compare to Baseline

# %%
env.training = False

electricity_consumption = []
done = False
obs = env.reset()
while not done:
        action = model.predict(obs, deterministic=True)
        obs, r, done, info = env.step([action[0][0]])
        electricity_consumption.append(info[0]['electricity_consumption'])

electricity_consumption = sum(electricity_consumption)

# %%
env.training = False

baseline_electricity_consumption = []
done = False
obs = env.reset()
while not done:
        # Always taking noop as action. This is the electricity demand if there would be no battery
        action = [0]
        obs, r, done, info = env.step(action)
        baseline_electricity_consumption.append(info[0]['electricity_consumption'])

baseline_electricity_consumption = sum(baseline_electricity_consumption)

# %%
# how much energy did we save by utilizing the battery?
electricity_consumption / baseline_electricity_consumption
# Out:
# 0.917375745039396
